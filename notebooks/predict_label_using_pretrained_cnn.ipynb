# %% [markdown]
# # Add Prediction to Unlabelled Data

# %%
import numpy as np
import pickle
import sys
import keras.preprocessing.image 
from keras.models import Sequential,Model,load_model
from keras.preprocessing.image import img_to_array
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from keras.layers import Activation, Dropout, Flatten, Dense,  GlobalMaxPooling2D, Lambda, Concatenate
from keras.applications.imagenet_utils import decode_predictions
import matplotlib.pyplot as plt
from keras.layers import Input
import csv
import pandas as pd   
import os
import h5py
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split

# %%
sys.argv[1] = "mhelabd"

# %%
#Global Variables
WANTED_BANDS = [3, 2, 1]
IMAGE_HEIGHT, IMAGE_WIDTH, NUM_BANDS, NUM_OG_BANDS = (64, 64, len(WANTED_BANDS), 13) 
MODEL_NAME = "Augmented-drop-neighbors-offset-CNN-({})-input-({}, {}, {})-bands-({})".format("Resnet50", IMAGE_HEIGHT, IMAGE_WIDTH, NUM_BANDS, str(WANTED_BANDS))
PATH = "/atlas/u/{}/data/kiln-scaling/models/{}/".format(sys.argv[1], MODEL_NAME) 
MODEL_WEIGHTS_PATH = PATH + "weights/trial_6_epoch_55.h5"
# DATASET = "bangladesh_2020_2021"
DATASET = "bangladesh_2019-2020"
DATA_PATH = "/atlas/u/mliu356/data/kiln-scaling/{}/".format(DATASET)
LABELLED_DATA_PATH = "/atlas/u/mhelabd/data/kiln-scaling/labelled_{}/".format(DATASET.replace("-", "_"))

# %%
def mkdirs(names):
    for name in names:
        if not os.path.exists(name):
            os.makedirs(name)
mkdirs([LABELLED_DATA_PATH])

# %%
def load_data_from_h5(filename):
    X, y = [], []
    with h5py.File(DATA_PATH + filename, "r") as f:
        print("extracting: ", filename) 
        X = np.array(f["images"][()])
        y = np.array(f["labels"][()])
        bounds = np.array(f["bounds"][()])
        indices = np.array(f["indices"][()])
    print("x shape: ", X.shape)
    print("y shape: ", y.shape)
    return X, y, bounds, indices

# %%
def make_model(weights="imagenet", 
               include_top=False, 
               load_weights=None, # path of weights
               loss=keras.losses.binary_crossentropy, 
               optimizer=keras.optimizers.Adam(), 
               metrics=[tf.keras.metrics.BinaryAccuracy(threshold=0.5)]):
    
    image_input = Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, NUM_BANDS))
    base_model = ResNet50(include_top=include_top, weights=weights, input_tensor=image_input, classes=2)
    x = base_model.output
    x = GlobalMaxPooling2D()(x)
    x = Dense(1024,activation='relu')(x) 
    x = Dense(1024,activation='relu')(x) 
    x = Dense(512,activation='relu')(x) 
    x = Dense(1, activation= 'sigmoid')(x)
    model = Model(inputs = base_model.input, outputs = x)
    
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
    if load_weights:
        model.load_weights(load_weights)
    return model

# %%
def save_h5_file(filename, X, y, bounds, indices, y_pred):
    filepath = LABELLED_DATA_PATH + filename
    print("Saving file", filepath)
    f = h5py.File(filepath, 'w')
    bounds_dset = f.create_dataset("bounds", data=bounds)
    examples_dset = f.create_dataset("images", data=X)
    labels_dset = f.create_dataset("labels", data=y)
    labels_dset = f.create_dataset("pred_labels", data=y_pred)
    labels_dset = f.create_dataset("indices", data=indices)
    f.close()

# %%
model = make_model(load_weights=MODEL_WEIGHTS_PATH)
for i, filename in enumerate(os.listdir(DATA_PATH)):
    X, y, bounds, indices = load_data_from_h5(filename)
    X_prime = np.array(X)\
            .reshape((-1, NUM_OG_BANDS, IMAGE_HEIGHT, IMAGE_WIDTH))
    X_prime = np.moveaxis(X_prime, 1, -1)[:, :, :, WANTED_BANDS]
    y_pred = model.predict(X_prime) > 0.5
    save_h5_file(filename, X, y, bounds,indices, y_pred)
# Out:
# extracting:  examples_77.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_77.hdf5
# extracting:  examples_3.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_3.hdf5
# extracting:  examples_46.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_46.hdf5
# extracting:  examples_24.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_24.hdf5
# extracting:  examples_86.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_86.hdf5
# extracting:  examples_15.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_15.hdf5
# extracting:  examples_7.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_7.hdf5
# extracting:  examples_42.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_42.hdf5
# extracting:  examples_38.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_38.hdf5
# extracting:  examples_73.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_73.hdf5
# extracting:  examples_11.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_11.hdf5
# extracting:  examples_20.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_20.hdf5
# extracting:  examples_82.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_82.hdf5
# extracting:  examples_67.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_67.hdf5
# extracting:  examples_56.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_56.hdf5
# extracting:  examples_34.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_34.hdf5
# extracting:  examples_19.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_19.hdf5
# extracting:  examples_52.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_52.hdf5
# extracting:  examples_63.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_63.hdf5
# extracting:  examples_28.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_28.hdf5
# extracting:  examples_30.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_30.hdf5
# extracting:  examples_66.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_66.hdf5
# extracting:  examples_57.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_57.hdf5
# extracting:  examples_35.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_35.hdf5
# extracting:  examples_53.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_53.hdf5
# extracting:  examples_18.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_18.hdf5
# extracting:  examples_29.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_29.hdf5
# extracting:  examples_62.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_62.hdf5
# extracting:  examples_31.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_31.hdf5
# extracting:  examples_76.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_76.hdf5
# extracting:  examples_2.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_2.hdf5
# extracting:  examples_47.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_47.hdf5
# extracting:  examples_25.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_25.hdf5
# extracting:  examples_87.hdf5
# x shape:  (562, 13, 64, 64)
# y shape:  (562, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_87.hdf5
# extracting:  examples_14.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_14.hdf5
# extracting:  examples_6.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_6.hdf5
# extracting:  examples_43.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_43.hdf5
# extracting:  examples_72.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_72.hdf5
# extracting:  examples_39.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_39.hdf5
# extracting:  examples_10.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_10.hdf5
# extracting:  examples_21.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_21.hdf5
# extracting:  examples_83.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_83.hdf5
# extracting:  examples_64.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_64.hdf5
# extracting:  examples_55.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_55.hdf5
# extracting:  examples_37.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_37.hdf5
# extracting:  examples_8.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_8.hdf5
# extracting:  examples_51.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_51.hdf5
# extracting:  examples_60.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_60.hdf5
# extracting:  examples_49.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_49.hdf5
# extracting:  examples_33.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_33.hdf5
# extracting:  examples_78.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_78.hdf5
# extracting:  examples_74.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_74.hdf5
# extracting:  examples_0.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_0.hdf5
# extracting:  examples_45.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_45.hdf5
# extracting:  examples_85.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_85.hdf5
# extracting:  examples_27.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_27.hdf5
# extracting:  examples_16.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_16.hdf5
# extracting:  examples_4.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_4.hdf5
# extracting:  examples_41.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_41.hdf5
# extracting:  examples_70.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_70.hdf5
# extracting:  examples_12.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_12.hdf5
# extracting:  examples_59.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_59.hdf5
# extracting:  examples_81.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_81.hdf5
# extracting:  examples_68.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_68.hdf5
# extracting:  examples_23.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_23.hdf5
# extracting:  examples_75.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_75.hdf5
# extracting:  examples_1.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_1.hdf5
# extracting:  examples_44.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_44.hdf5
# extracting:  examples_84.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_84.hdf5
# extracting:  examples_26.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_26.hdf5
# extracting:  examples_17.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_17.hdf5
# extracting:  examples_5.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_5.hdf5
# extracting:  examples_40.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_40.hdf5
# extracting:  examples_71.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_71.hdf5
# extracting:  examples_58.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_58.hdf5
# extracting:  examples_13.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_13.hdf5
# extracting:  examples_80.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_80.hdf5
# extracting:  examples_22.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_22.hdf5
# extracting:  examples_69.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_69.hdf5
# extracting:  examples_65.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_65.hdf5
# extracting:  examples_54.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_54.hdf5
# extracting:  examples_36.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_36.hdf5
# extracting:  examples_9.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_9.hdf5
# extracting:  examples_50.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_50.hdf5
# extracting:  examples_61.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_61.hdf5
# extracting:  examples_48.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_48.hdf5
# extracting:  examples_79.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_79.hdf5
# extracting:  examples_32.hdf5
# x shape:  (999, 13, 64, 64)
# y shape:  (999, 1)
# Saving file /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_32.hdf5

# %% [markdown]
# # Testing

# %%
filename = "/atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_32.hdf5"

# %%
 with h5py.File(filename, "r") as f:
    print("extracting: ", filename) 
    X = np.array(f["images"][()])
    y = np.array(f["labels"][()])
    bounds = np.array(f["bounds"][()])
    y_pred = np.array(f["pred_labels"][()])      
    print(y.shape)
    print(y_pred.shape)
# Out:
# extracting:  /atlas/u/mhelabd/data/kiln-scaling/labelled_bangladesh_2020_2021/examples_32.hdf5
# (999, 1)
# (999, 1)

# %%
len(os.listdir(DATA_PATH)), len(os.listdir(LABELLED_DATA_PATH))
# Out:
# (87, 87)
